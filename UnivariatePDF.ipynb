# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/home/teja1805/Downloads/Stock/sp500_join_closes.csv")
data
# Out:
#             Date         MMM         ABT        ABBV        ABMD         ACN  \
# 0     2007-12-31   57.223072   19.295296         NaN   15.540000   27.638117
# 1     2008-01-02   56.130451   19.178459         NaN   15.250000   27.661127
# 2     2008-01-03   56.123676   19.061621         NaN   15.020000   27.185524
# 3     2008-01-04   55.485764   19.171581         NaN   14.480000   26.778976
# 4     2008-01-07   55.044628   19.759212         NaN   14.740000   26.057917
# ...          ...         ...         ...         ...         ...         ...
# 3270  2020-12-24  169.150864  106.700714   98.533798  303.410004  254.158463
# 3271  2020-12-28  169.335007  106.149239   98.715096  312.910004  256.509430
# 3272  2020-12-29  168.501465  106.681023   99.907883  320.929993  254.612869
# 3273  2020-12-30  168.753479  106.789345  100.451790  323.920013  254.395554
# 3274  2020-12-31  169.412552  107.823349  102.245750  324.200012  258.020752
#
# ...

# %%
df=pd.read_csv("/home/teja1805/Downloads/Data Analysis w_ Python 3 and Pandas/avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
dfpd=pd.DataFrame()
for i in data.columns[1:100]:
    print(i)
# Out:
# MMM
# ABT
# ABBV
# ABMD
# ACN
# ATVI
# ADBE
# AMD
# AAP
# AES
# AFL
# A
# APD
# AKAM
# ALK
# ALB
# ARE
# ALGN
# ALLE
# LNT
# ALL
# GOOGL
# GOOG
# MO
# AMZN
# AMCR
# AEE
# AAL
# AEP
# AXP
# AIG
# AMT
# AWK
# AMP
# ABC
# AME
# AMGN
# APH
# ADI
# ANSS
# ANTM
# AON
# AOS
# APA
# AAPL
# AMAT
# APTV
# ADM
# ANET
# AJG
# AIZ
# T
# ATO
# ADSK
# ADP
# AZO
# AVB
# AVY
# BKR
# BLL
# BAC
# BBWI
# BAX
# BDX
# BBY
# BIO
# TECH
# BIIB
# BLK
# BK
# BA
# BKNG
# BWA
# BXP
# BSX
# BMY
# AVGO
# BR
# BRO
# CHRW
# CDNS
# CZR
# CPB
# COF
# CAH
# KMX
# CCL
# CARR
# CTLT
# CAT
# CBOE
# CBRE
# CDW
# CE
# CNC
# CNP
# CDAY
# CERN
# CF

# %%
data["ABMD"][-1:]
# Out:
# 3274    324.200012
# Name: ABMD, dtype: float64

# %%
count=0
lis=[]
for i in data.columns[1:100]:
    ma=max(data[i])
    j=data[i][-1:]*2
    if (ma>j).bool():
        print(i)
        lis.append(i)
        print("max:",ma,"\n")
        print("last:",data[i][-1:])     
        count=count+1
print("Total Count:",count)
# Out:
# AAL
# max: 56.988731384277344
#
# last: 3274    15.77
# Name: AAL, dtype: float64
# AIG
# max: 804.034423828125
#
# last: 3274    37.158783
# Name: AIG, dtype: float64
# APA
# max: 121.37223052978516
#
# last: 3274    14.096284
# Name: APA, dtype: float64
# BKR
# max: 48.57703399658203
#
# last: 3274    20.213726
# Name: BKR, dtype: float64
# BBWI
# max: 62.52936172485352
#
# last: 3274    29.862652
# Name: BBWI, dtype: float64
# BA
# max: 430.2999877929688
#
# last: 3274    214.059998
# Name: BA, dtype: float64
# CCL
# max: 66.21757507324219
#
# last: 3274    21.66
# Name: CCL, dtype: float64
# Total Count: 7

# %%
data["GOOG"]
# Out:
# 0        344.448914
# 1        341.315674
# 2        341.385406
# 3        327.273285
# 4        323.412781
#            ...
# 3270    1738.849976
# 3271    1776.089966
# 3272    1758.719971
# 3273    1739.520020
# 3274    1751.880005
# Name: GOOG, Length: 3275, dtype: float64

# %%
max(data["GOOG"])
# Out:
# 1827.989990234375

# %%
i="GOOG"
max(data[i])
# Out:
# 1827.989990234375

# %%
data[i][-1:]*1.2
# Out:
# 3274    2102.256006
# Name: GOOG, dtype: float64

# %%
data["AAL"]
# Out:
# 0       13.867729
# 1       12.557316
# 2       11.991673
# 3       11.699421
# 4       11.529730
#           ...
# 3270    15.660000
# 3271    16.059999
# 3272    15.860000
# 3273    16.150000
# 3274    15.770000
# Name: AAL, Length: 3275, dtype: float64

# %%
for i in lis:
    fig=plt.figure()
    plt.hist(data[i],bins=10)
    fig.show()
# Out:
# <ipython-input-12-61db867cb2fb>:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
count=0
for i in data.columns[100:201]:
    ma=max(data[i])
    j=data[i][-1:]*2
    if (ma>j).bool():
        print(i)
        lis.append(i)
        print("max:",ma,"\n")
        print("last:",data[i][-1:])     
        count=count+1
print("Total Count:",count)
# Out:
# C
# max: 244.3805389404297
#
# last: 3274    59.832924
# Name: C, dtype: float64
# CTRA
# max: 41.61000061035156
#
# last: 3274    16.280001
# Name: CTRA, dtype: float64
# DVN
# max: 98.41697692871094
#
# last: 3274    15.357415
# Name: DVN, dtype: float64
# DISH
# max: 79.41000366210938
#
# last: 3274    32.34
# Name: DISH, dtype: float64
# DXC
# max: 92.3997573852539
#
# last: 3274    25.75
# Name: DXC, dtype: float64
# EOG
# max: 122.41812896728516
#
# last: 3274    48.189827
# Name: EOG, dtype: float64
# Total Count: 6

# %%
for i in lis:
    fig=plt.figure()
    plt.hist(data[i],bins=10)
    fig.show()
# Out:
# <ipython-input-14-61db867cb2fb>:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
lis
# Out:
# ['AAL',
#  'AIG',
#  'APA',
#  'BKR',
#  'BBWI',
#  'BA',
#  'CCL',
#  'C',
#  'CTRA',
#  'DVN',
#  'DISH',
#  'DXC',
#  'EOG']

# %%
len(lis)
# Out:
# 13

# %%
for i in lis:
    fig=plt.figure()
    plt.hist(data[i],bins=20)
    plt.xlabel(i)
    fig.show()
# Out:
# <ipython-input-17-c17bfa644a8c>:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
count=0
for i in data.columns[201:300]:
    ma=max(data[i])
    j=data[i][-1:]*2
    if (ma>j).bool():
        print(i)
        lis.append(i)
        print("max:",ma,"\n")
        print("last:",data[i][-1:])     
        count=count+1
print("Total Count:",count)
# Out:
# GE
# max: 280.67437744140625
#
# last: 3274    86.316711
# Name: GE, dtype: float64
# HAL
# max: 64.75293731689453
#
# last: 3274    18.783207
# Name: HAL, dtype: float64
# HES
# max: 111.99205017089844
#
# last: 3274    52.275017
# Name: HES, dtype: float64
# LUMN
# max: 22.529788970947266
#
# last: 3274    9.206773
# Name: LUMN, dtype: float64
# MRO
# max: 37.03239059448242
#
# last: 3274    6.573964
# Name: MRO, dtype: float64
# Total Count: 5

# %%
len(lis)
# Out:
# 18

# %%
for i in lis:
    fig=plt.figure()
    plt.hist(data[i],bins=20)
    plt.xlabel(i)
    fig.show()
# Out:
# <ipython-input-20-c17bfa644a8c>:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
count=0
for i in data.columns[300:401]:
    ma=max(data[i])
    j=data[i][-1:]*2
    if (ma>j).bool():
        print(i)
        lis.append(i)
        print("max:",ma,"\n")
        print("last:",data[i][-1:])     
        count=count+1
print("Total Count:",count)
# Out:
# MGM
# max: 79.39000701904297
#
# last: 3274    31.503132
# Name: MGM, dtype: float64
# MHK
# max: 284.82000732421875
#
# last: 3274    140.949997
# Name: MHK, dtype: float64
# TAP
# max: 100.4503402709961
#
# last: 3274    44.864269
# Name: TAP, dtype: float64
# MOS
# max: 130.44454956054688
#
# last: 3274    22.873838
# Name: MOS, dtype: float64
# NWL
# max: 45.4204216003418
#
# last: 3274    20.67074
# Name: NWL, dtype: float64
# OXY
# max: 76.49950408935547
#
# last: 3274    17.291311
# Name: OXY, dtype: float64
# Total Count: 6

# %%
count=0
for i in data.columns[401:500]:
    ma=max(data[i])
    j=data[i][-1:]*2
    if (ma>j).bool():
        print(i)
        lis.append(i)
        print("max:",ma,"\n")
        print("last:",data[i][-1:])     
        count=count+1
print("Total Count:",count)
# Out:
# SLB
# max: 93.75985717773438
#
# last: 3274    21.545717
# Name: SLB, dtype: float64
# SPG
# max: 175.37306213378906
#
# last: 3274    82.497803
# Name: SPG, dtype: float64
# UAA
# max: 52.04999923706055
#
# last: 3274    17.17
# Name: UAA, dtype: float64
# UAL
# max: 96.6999969482422
#
# last: 3274    43.25
# Name: UAL, dtype: float64
# VTRS
# max: 75.52333068847656
#
# last: 3274    18.607773
# Name: VTRS, dtype: float64
# WBA
# max: 82.18673706054688
#
# last: 3274    39.166107
# Name: WBA, dtype: float64
# WMB
# max: 40.79790496826172
#
# last: 3274    19.10397
# Name: WMB, dtype: float64
# Total Count: 7

# %%
len(lis)
# Out:
# 31

# %%
lis
# Out:
# ['AAL',
#  'AIG',
#  'APA',
#  'BKR',
#  'BBWI',
#  'BA',
#  'CCL',
#  'C',
#  'CTRA',
#  'DVN',
#  'DISH',
#  'DXC',
#  'EOG',
#  'GE',
#  'HAL',
#  'HES',
#  'LUMN',
#  'MRO',
#  'MGM',
#  'MHK',
#  'TAP',
#  'MOS',
#  'NWL',
#  'OXY',
#  'SLB',
#  'SPG',
#  'UAA',
#  'UAL',
#  'VTRS',
#  'WBA',
#  'WMB']

# %%
len(set(lis))
# Out:
# 31

# %%
lis
# Out:
# ['AAL',
#  'AIG',
#  'APA',
#  'BKR',
#  'BBWI',
#  'BA',
#  'CCL',
#  'C',
#  'CTRA',
#  'DVN',
#  'DISH',
#  'DXC',
#  'EOG',
#  'GE',
#  'HAL',
#  'HES',
#  'LUMN',
#  'MRO',
#  'MGM',
#  'MHK',
#  'TAP',
#  'MOS',
#  'NWL',
#  'OXY',
#  'SLB',
#  'SPG',
#  'UAA',
#  'UAL',
#  'VTRS',
#  'WBA',
#  'WMB']

# %%
for i in range(len(lis)):
    if(lis[i] in lis[i+1:]):
        print(lis[i])

# %%
lis=list(set(lis))

# %%
len(lis)
# Out:
# 31

# %%
len(set(lis))
# Out:
# 31

# %%
for i in lis:
    fig=plt.figure()
    plt.hist(data[i],bins=20)
    plt.xlabel(i)
    fig.show()
# Out:
# <ipython-input-31-c17bfa644a8c>:5: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# <ipython-input-31-c17bfa644a8c>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig=plt.figure()

# %%
#DVN,HES,HAL,APA,BKR

# %%
meanl=[]
stdl=[]
for i in lis:
    meanl.append(mean(data[i]))
    stdl.append(std(data[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-b4cbc35de06f> in <module>
#       2 stdl=[]
#       3 for i in lis:
# ----> 4     meanl.append(mean(data[i]))
#       5     stdl.append(std(data[i]))
#
# NameError: name 'mean' is not defined

# %%
from statistics import mean

# %%
meanl=[]
stdl=[]
for i in lis:
    meanl.append(mean(data[i]))
    stdl.append(np.std(data[i]))

# %%
len(meanl)
# Out:
# 0

# %%
len(stdl)
# Out:
# 0

# %%
print(meanl)
# Out:
# []

# %%
print(stdl)
# Out:
# []

# %%
len(lis)
# Out:
# 31

# %%
print(lis)
# Out:
# ['TAP', 'HES', 'SPG', 'CCL', 'C', 'MOS', 'EOG', 'GE', 'AIG', 'MHK', 'BKR', 'DISH', 'NWL', 'HAL', 'VTRS', 'MGM', 'AAL', 'SLB', 'UAA', 'WMB', 'DVN', 'LUMN', 'OXY', 'BA', 'WBA', 'CTRA', 'UAL', 'APA', 'MRO', 'DXC', 'BBWI']

# %%
for i in lis:
    if i in ('DVN','HES','HAL','APA','BKR'):
        fig=plt.figure()
        plt.hist(data[i])
        plt.xlabel(i)
        plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-7c5367431c5f> in <module>
# ----> 1 probabilities=[data.pdf(j) for j in data["BKR"]]
#
# <ipython-input-47-7c5367431c5f> in <listcomp>(.0)
# ----> 1 probabilities=[data.pdf(j) for j in data["BKR"]]
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'pdf'
