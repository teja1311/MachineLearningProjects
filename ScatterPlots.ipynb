# %%
import pandas as pd
location="/home/teja1805/Downloads/Stock/Tesla.csv"
data=pd.read_csv(location)
data.head()
# Out:
#          Date   High    Low   Open  Close      Volume  Adj Close
# 0  2010-06-29  5.000  3.508  3.800  4.778  93831500.0      4.778
# 1  2010-06-30  6.084  4.660  5.158  4.766  85935500.0      4.766
# 2  2010-07-01  5.184  4.054  5.000  4.392  41094000.0      4.392
# 3  2010-07-02  4.620  3.742  4.600  3.840  25699000.0      3.840
# 4  2010-07-06  4.000  3.166  4.000  3.222  34334500.0      3.222

# %%
data=pd.read_csv("/home/teja1805/Downloads/Stock/sp500_join_closes.csv")

# %%
data.head()
# Out:
#          Date        MMM        ABT  ABBV   ABMD        ACN       ATVI  \
# 0  2007-12-31  57.223072  19.295296   NaN  15.54  27.638117  13.243873
# 1  2008-01-02  56.130451  19.178459   NaN  15.25  27.661127  12.677551
# 2  2008-01-03  56.123676  19.061621   NaN  15.02  27.185524  12.454592
# 3  2008-01-04  55.485764  19.171581   NaN  14.48  26.778976  12.414458
# 4  2008-01-07  55.044628  19.759212   NaN  14.74  26.057917  12.481347
#
#         ADBE   AMD        AAP  ...       WLTW       WYNN        XEL  \
# 0  42.730000  7.50  35.917763  ...  72.144402  69.272423  13.568501
# 1  41.709999  7.14  35.539600  ...  68.572327  67.573540  13.328033
# 2  41.790001  6.77  35.879944  ...  69.199348  65.287712  13.406185
# 3  40.360001  6.25  33.724319  ...  69.104301  64.991165  13.255898
# 4  40.240002  6.08  35.246494  ...  69.275322  64.385757  13.460289
#
#         XLNX  XYL        YUM       ZBRA        ZBH       ZION  ZTS
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.filterwarnings("ignore")
# %config InlineBackend.figure_format='retina'

# %%
len(data)
# Out:
# 3275

# %%
data.columns
# Out:
# Index(['Date', 'MMM', 'ABT', 'ABBV', 'ABMD', 'ACN', 'ATVI', 'ADBE', 'AMD',
#        'AAP',
#        ...
#        'WLTW', 'WYNN', 'XEL', 'XLNX', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION',
#        'ZTS'],
#       dtype='object', length=503)

# %%
data.dropna(inplace=True)
len(data.columns)
# Out:
# 503

# %%
data=data.dropna()

# %%
data.head()
# Out:
#             Date         MMM        ABT       ABBV        ABMD         ACN  \
# 3075  2020-03-19  129.658524  72.534035  65.118767  140.509995  154.686829
# 3076  2020-03-20  117.759109  66.205559  63.066055  130.509995  146.332794
# 3077  2020-03-23  111.139931  61.162251  59.107239  132.339996  140.233124
# 3078  2020-03-24  125.142052  67.850960  61.847252  143.669998  153.076538
# 3079  2020-03-25  124.029404  68.882980  62.232128  146.889999  148.167557
#
#            ATVI        ADBE        AMD        AAP  ...        WLTW       WYNN  \
# 3075  53.517197  307.510010  39.820000  84.590240  ...  149.035248  46.580002
# 3076  51.460743  295.339996  39.610001  73.825821  ...  149.074341  51.970001
# 3077  55.830708  307.269989  41.639999  77.240120  ...  144.122421  57.570000
# 3078  53.813805  310.000000  46.220001  84.993652  ...  165.893173  66.559998
# 3079  52.271461  305.910004  44.630001  88.919632  ...  159.945038  75.059998
#
# ...

# %%
len(data)
# Out:
# 200

# %%
location="/home/teja1805/Downloads/Stock/Tesla.csv"
data=pd.read_csv(location)

# %%
data.dropna(axis=1,inplace=True)

# %%
len(data)
# Out:
# 2647

# %%
data.columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
data=pd.read_csv("/home/teja1805/Downloads/Stock/sp500_join_closes.csv")

# %%
data.dropna(axis=1,inplace=True)

# %%
len(data)
# Out:
# 3275

# %%
len(data.columns)
# Out:
# 435

# %%
date=data["Date"]

# %%
date.head()
# Out:
# 0    2007-12-31
# 1    2008-01-02
# 2    2008-01-03
# 3    2008-01-04
# 4    2008-01-07
# Name: Date, dtype: object

# %%
date
# Out:
# Series([], Name: Date, dtype: object)

# %%
len(date)
# Out:
# 0

# %%
len(data["Date"])
# Out:
# 3275

# %%
date=pd.DataFrame(data["Date"])

# %%
date
# Out:
#             Date
# 0     2007-12-31
# 1     2008-01-02
# 2     2008-01-03
# 3     2008-01-04
# 4     2008-01-07
# ...          ...
# 3270  2020-12-24
# 3271  2020-12-28
# 3272  2020-12-29
# 3273  2020-12-30
# 3274  2020-12-31
#
# [3275 rows x 1 columns]

# %%
date.columns
# Out:
# Index(['Date'], dtype='object')

# %%
date.index
# Out:
# RangeIndex(start=0, stop=3275, step=1)

# %%
date.set_index("Date")
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
data.head()
# Out:
#          Date        MMM        ABT   ABMD        ACN       ATVI       ADBE  \
# 0  2007-12-31  57.223072  19.295296  15.54  27.638117  13.243873  42.730000
# 1  2008-01-02  56.130451  19.178459  15.25  27.661127  12.677551  41.709999
# 2  2008-01-03  56.123676  19.061621  15.02  27.185524  12.454592  41.790001
# 3  2008-01-04  55.485764  19.171581  14.48  26.778976  12.414458  40.360001
# 4  2008-01-07  55.044628  19.759212  14.74  26.057917  12.481347  40.240002
#
#     AMD        AAP        AES  ...        WHR        WMB       WLTW  \
# 0  7.50  35.917763  16.208523  ...  56.171043  15.355135  72.144402
# 1  7.14  35.539600  15.996345  ...  54.966816  15.355135  68.572327
# 2  6.77  35.879944  15.958457  ...  54.443844  15.749956  69.199348
# 3  6.25  33.724319  16.019083  ...  52.049202  15.273594  69.104301
# 4  6.08  35.246494  16.663174  ...  52.400146  15.196346  69.275322
#
#         WYNN        XEL       XLNX        YUM       ZBRA        ZBH       ZION
# ...

# %%
data.tail()
# Out:
#             Date         MMM         ABT        ABMD         ACN       ATVI  \
# 3270  2020-12-24  169.150864  106.700714  303.410004  254.158463  90.521706
# 3271  2020-12-28  169.335007  106.149239  312.910004  256.509430  90.989441
# 3272  2020-12-29  168.501465  106.681023  320.929993  254.612869  90.929733
# 3273  2020-12-30  168.753479  106.789345  323.920013  254.395554  91.138718
# 3274  2020-12-31  169.412552  107.823349  324.200012  258.020752  92.402596
#
#             ADBE        AMD         AAP        AES  ...         WHR  \
# 3270  499.859985  91.809998  158.870193  22.711819  ...  188.494156
# 3271  498.950012  91.599998  157.011383  22.741098  ...  180.679245
# 3272  502.109985  90.620003  154.925140  22.750858  ...  178.737701
# 3273  497.450012  92.290001  155.884232  22.233572  ...  179.898727
# 3274  500.119995  91.709999  155.735901  22.936300  ...  176.093750
#
#             WMB        WLTW        WYNN        XEL        XLNX         YUM  \
# ...

# %%
features=["Date","ABMD"]
data[features].hist(figsize=(5,8))
# Out:
# array([[<AxesSubplot:title={'center':'ABMD'}>]], dtype=object)

# %%
data["ABMD"].hist(figsize=(5,8))
# Out:
# <AxesSubplot:>

# %%
data.hist(data.Date,data.ABMD)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-2a7f24e8ccb7> in <module>
# ----> 1 data.hist(data.Date,data.ABMD)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     385         raise ValueError("Cannot use both legend and label")
#     386     if by is not None:
# --> 387         axes = _grouped_hist(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-7e8edbe7962b> in <module>
# ----> 1 date.date
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'date'

# %%
data.hist(date["Date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-0ced3377456b> in <module>
# ----> 1 data.hist(date["Date"])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     209     """
#     210     plot_backend = _get_plot_backend(backend)
# --> 211     return plot_backend.hist_frame(
#     212         data,
#     213         column=column,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     408         if not isinstance(column, (list, np.ndarray, ABCIndexClass)):
#     409             column = [column]
# --> 410         data = data[column]
# ...

# %%
    data.head(2).hist(figsize=(15,12),bins=20,color="#000000")

# %%
data.head(2).hist(figsize=(15,12),bins=20,color="#000000")
# Out:
# array([[<AxesSubplot:title={'center':'MMM'}>,
#         <AxesSubplot:title={'center':'ABT'}>,
#         <AxesSubplot:title={'center':'ABMD'}>,
#         <AxesSubplot:title={'center':'ACN'}>,
#         <AxesSubplot:title={'center':'ATVI'}>,
#         <AxesSubplot:title={'center':'ADBE'}>,
#         <AxesSubplot:title={'center':'AMD'}>,
#         <AxesSubplot:title={'center':'AAP'}>,
#         <AxesSubplot:title={'center':'AES'}>,
#         <AxesSubplot:title={'center':'AFL'}>,
#         <AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'APD'}>,
#         <AxesSubplot:title={'center':'AKAM'}>,
#         <AxesSubplot:title={'center':'ALK'}>,
#         <AxesSubplot:title={'center':'ALB'}>,
#         <AxesSubplot:title={'center':'ARE'}>,
#         <AxesSubplot:title={'center':'ALGN'}>,
#         <AxesSubplot:title={'center':'LNT'}>,
#         <AxesSubplot:title={'center':'ALL'}>,
#         <AxesSubplot:title={'center':'GOOGL'}>,
# ...

# %%
df=pd.read_csv("/home/teja1805/Downloads/Data Analysis w_ Python 3 and Pandas/avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018])

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
features=["AveragePrice"]
df[features].hist(figsize=(8,5),color="#000000",bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'AveragePrice'}>]], dtype=object)

# %%
df[features].plot(kind='density',figsize=(10,4))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[features].plot(kind='density',figsize=(10,4),sharex=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[features].plot(kind='density',figsize=(10,4),sharex=False)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[features].plot(kind='density',figsize=(10,4),subplots=False,sharex=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df[features].plot(kind='line',figsize=(10,4),sharex=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="hexbin",figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-f54ddac8e153> in <module>
# ----> 1 df.plot(kind="hexbin",figsize=(10,5))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     892         if kind in self._dataframe_kinds:
#     893             if isinstance(data, ABCDataFrame):
# --> 894                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     895             else:
#     896                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      58                 ax = plt.gca()
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
# ---> 60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
#      61     plot_obj.generate()
# ...

# %%
data.plot(x=data["Date"],y=data["ABMD"],kind="kde")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-9cc7571a7d37> in <module>
# ----> 1 data.plot(x=data["Date"],y=data["ABMD"],kind="kde")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2906             if is_iterator(key):
#    2907                 key = list(key)
# -> 2908             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2909
# ...

# %%
sns.scatterplot(x=df[""],y=df["AveragePrice"])
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
data
# Out:
#             Date         MMM         ABT        ABMD         ACN       ATVI  \
# 0     2007-12-31   57.223072   19.295296   15.540000   27.638117  13.243873
# 1     2008-01-02   56.130451   19.178459   15.250000   27.661127  12.677551
# 2     2008-01-03   56.123676   19.061621   15.020000   27.185524  12.454592
# 3     2008-01-04   55.485764   19.171581   14.480000   26.778976  12.414458
# 4     2008-01-07   55.044628   19.759212   14.740000   26.057917  12.481347
# ...          ...         ...         ...         ...         ...        ...
# 3270  2020-12-24  169.150864  106.700714  303.410004  254.158463  90.521706
# 3271  2020-12-28  169.335007  106.149239  312.910004  256.509430  90.989441
# 3272  2020-12-29  168.501465  106.681023  320.929993  254.612869  90.929733
# 3273  2020-12-30  168.753479  106.789345  323.920013  254.395554  91.138718
# 3274  2020-12-31  169.412552  107.823349  324.200012  258.020752  92.402596
#
# ...

# %%
sns.scatterplot(x=data["ABMD"],y=data["ADBE"])
# Out:
# <AxesSubplot:xlabel='ABMD', ylabel='ADBE'>

# %%
sns.regplot(data=data,x="ABMD",y="ADBE")
# Out:
# <AxesSubplot:xlabel='ABMD', ylabel='ADBE'>

# %%
sns.scatterplot(x=data.MMM,y=data.WMB,color='#ffff00')
# Out:
# <AxesSubplot:xlabel='MMM', ylabel='WMB'>

# %%
sns.regplot(data=data,x="ABMD",y="ADBE",scatter_kws={"color":'#ffff00'},line_kws={"color":"crimson"})
# Out:
# <AxesSubplot:xlabel='ABMD', ylabel='ADBE'>

# %%
sns.scatterplot(data=df,x="TotalVolume",y="AveragePrice",hue="type")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-6e6e5ee5d27e> in <module>
# ----> 1 sns.scatterplot(data=df,x="TotalVolume",y="AveragePrice",hue="type")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     792
#     793     variables = _ScatterPlotter.get_semantics(locals())
# --> 794     p = _ScatterPlotter(
# ...

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TotalVolume'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-102-e838987e6ab6> in <module>
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df=df.rename(columns={'Total Volume':'TotalVolume'})

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'TotalVolume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"])
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue="type")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-6a6995600992> in <module>
# ----> 1 sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue="type")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     792
#     793     variables = _ScatterPlotter.get_semantics(locals())
# --> 794     p = _ScatterPlotter(
# ...

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  TotalVolume     4046       4225  \
# 0               0  2015-12-27          1.33     64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35     54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93    118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08     78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28     51039.60   941.48   43838.39
# ...           ...         ...           ...          ...      ...        ...
# 18244           7  2018-02-04          1.63     17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71     13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87     13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93     16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62     17489.58  2894.77    2356.13
#
# ...

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["type"])
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.regplot(x=df["TotalVolume"],y=df["AveragePrice"],scatter_kws={"color":"yellow"},line_kws={"color":"crimson"})
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["year"])
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["type"],style=df["type"])
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.scatterplot(figsize=(10,8),x=df["TotalVolume"],y=df["AveragePrice"],hue=df["type"],data=df,style="year")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-122-911192babc6b> in <module>
# ----> 1 sns.scatterplot(figsize=(10,8),x=df["TotalVolume"],y=df["AveragePrice"],hue=df["type"],data=df,style="year")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     811     p._attach(ax)
#     812
# --> 813     p.plot(ax, kwargs)
#     814
#     815     return ax
#
# ...

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["type"],data=df,style="year")
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["year"],palette="deep")
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
region=df["region"].unique()[:5]

# %%
region
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston'],
#       dtype=object)

# %%
sns.scatterplot(x=df["TotalVolume"],y=df["AveragePrice"],hue=df["year"],style=df["region"],palette="deep")
# Out:
# <AxesSubplot:xlabel='TotalVolume', ylabel='AveragePrice'>

# %%
gb=df.groupby("region")[[]]

# %%
gb

# %%
gb.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 52, 53, 54, 55, 56, 104, 105, 106, 107, 108, 156, 157, 158, 159, 160, 208, 209, 210, 211, 212, 260, 261, 262, 263, 264, 312, 313, 314, 315, 316, 364, 365, 366, 367, 368, 416, 417, 418, 419, 420, 468, 469, 470, 471, 472, 520, 521, 522, 523, 524, 572, 573, 574, 575, 576, 624, 625, 626, 627, 628, 676, 677, 678, 679, 680, 728, 729, 730, 731, 732, 780, 781, 782, 783, 784, 832, 833, 834, 835, 836, 884, 885, 886, 887, 888, 936, 937, 938, 939, 940, 988, 989, 990, 991, 992, ...]
#
# [270 rows x 0 columns]

# %%
gb=df.groupby("state")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-827af77bd275> in <module>
# ----> 1 gb=df.groupby("state")
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ...

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  TotalVolume     4046       4225  \
# 0               0  2015-12-27          1.33     64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35     54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93    118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08     78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28     51039.60   941.48   43838.39
# ...           ...         ...           ...          ...      ...        ...
# 18244           7  2018-02-04          1.63     17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71     13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87     13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93     16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62     17489.58  2894.77    2356.13
#
# ...

# %%
gb=df.groupby("region")

# %%
gb.head()
# Out:
#       Unnamed: 0        Date  AveragePrice  TotalVolume       4046       4225  \
# 0              0  2015-12-27          1.33     64236.62    1036.74   54454.85
# 1              1  2015-12-20          1.35     54876.98     674.28   44638.81
# 2              2  2015-12-13          0.93    118220.22     794.70  109149.67
# 3              3  2015-12-06          1.08     78992.15    1132.00   71976.41
# 4              4  2015-11-29          1.28     51039.60     941.48   43838.39
# ...          ...         ...           ...          ...        ...        ...
# 2756           0  2015-12-27          0.71    776404.39  451904.51  141599.36
# 2757           1  2015-12-20          0.83    649885.76  389110.55  108176.29
# 2758           2  2015-12-13          0.78    646041.56  437780.91  100110.13
# 2759           3  2015-12-06          0.74    623231.77  398871.12  133434.18
# 2760           4  2015-11-29          0.81    519028.45  335446.83  103635.94
#
# ...

# %%
gb.describe()
# Out:
#                     Unnamed: 0                                               \
#                          count       mean        std  min   25%   50%   75%
# region
# Albany                   338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# Atlanta                  338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# BaltimoreWashington      338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# Boise                    338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# Boston                   338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# BuffaloRochester         338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# California               338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# Charlotte                338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# Chicago                  338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# CincinnatiDayton         338.0  24.236686  15.506203  0.0  10.0  24.0  38.0
# ...

# %%
gb.set_index("region",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-cd092a3036ff> in <module>
# ----> 1 gb.set_index("region",inplace=True)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     701             return self[attr]
#     702
# --> 703         raise AttributeError(
#     704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'set_index'

# %%
sns.scatterplot(x=gb["TotalVolume"],y=gb["AveragePrice"],hue=gb["year"],style=gb["region"],palette="deep")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_core.py in categorical_order(vector, order)
#    1455             try:
# -> 1456                 order = vector.cat.categories
#    1457             except (TypeError, AttributeError):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py in __init__(self, data)
# ...

# %%
data
# Out:
#             Date         MMM         ABT        ABMD         ACN       ATVI  \
# 0     2007-12-31   57.223072   19.295296   15.540000   27.638117  13.243873
# 1     2008-01-02   56.130451   19.178459   15.250000   27.661127  12.677551
# 2     2008-01-03   56.123676   19.061621   15.020000   27.185524  12.454592
# 3     2008-01-04   55.485764   19.171581   14.480000   26.778976  12.414458
# 4     2008-01-07   55.044628   19.759212   14.740000   26.057917  12.481347
# ...          ...         ...         ...         ...         ...        ...
# 3270  2020-12-24  169.150864  106.700714  303.410004  254.158463  90.521706
# 3271  2020-12-28  169.335007  106.149239  312.910004  256.509430  90.989441
# 3272  2020-12-29  168.501465  106.681023  320.929993  254.612869  90.929733
# 3273  2020-12-30  168.753479  106.789345  323.920013  254.395554  91.138718
# 3274  2020-12-31  169.412552  107.823349  324.200012  258.020752  92.402596
#
# ...

# %%
sns.scatterplot(x=data.MMM,y=data.WMB,color='#ffff00',data=data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-157-4decfbfaad13> in <module>
# ----> 1 sns.scatterplot(x=data.MMM,y=data.WMB,color='#ffff00',data=data,size="size")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     792
#     793     variables = _ScatterPlotter.get_semantics(locals())
# --> 794     p = _ScatterPlotter(
# ...

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  TotalVolume     4046       4225  \
# 0               0  2015-12-27          1.33     64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35     54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93    118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08     78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28     51039.60   941.48   43838.39
# ...           ...         ...           ...          ...      ...        ...
# 18244           7  2018-02-04          1.63     17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71     13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87     13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93     16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62     17489.58  2894.77    2356.13
#
# ...

# %%
sns.scatterplot(data=df,x="AveragePrice",y="TotalVolume",hue="year",palette="deep",)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='TotalVolume'>

# %%
sns.scatterplot(data=df,x="AveragePrice",y="TotalVolume",hue="year",palette="deep",hue_norm=(0,4))
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='TotalVolume'>

# %%
sns.lmplot(data=df,x="AveragePrice",y="TotalVolume",hue="year")

# %%
sns.lmplot(data=df,x="AveragePrice",y="TotalVolume",hue="type")

# %%
sns.scatterplot(data=df,x="type",y="AveragePrice")
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
sns.swarmplot(data=df,x="type",y="AveragePrice")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-f6e047d9b602> in <module>
# ----> 1 sns.swarmplot(data=df,x="type",y="AveragePrice")
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    3004                        linewidth=linewidth))
#    3005
# -> 3006     plotter.plot(ax, kwargs)
#    3007     return ax
#    3008
#
# ~/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py in plot(self, ax, kws)
#    1418     def plot(self, ax, kws):
# ...
